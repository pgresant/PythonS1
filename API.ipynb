# %%
import pandas as pd
import requests

dress_feuil9 = "https://data.drees.solidarites-sante.gouv.fr/api/datasets/1.0/3647_ivg/attachments/donnees_feuil9_csv/"
response_feuil9 = pd.read_csv(dress_feuil9, sep=";", encoding="latin")

# %%
response_feuil9.head()
# Out:
#                   ZONE_GEO IVG_GO IVG_MG IVG_SF IVG_AUT  ANNEE  Unnamed: 6
# 0                      Ain      0     88    288      NC   2024         NaN
# 1                    Aisne     NC     NC     82       0   2024         NaN
# 2                   Allier     NC     NC    409       0   2024         NaN
# 3  Alpes-de-Haute-Provence      0     NC     NC       0   2024         NaN
# 4             Hautes-Alpes     NC    270     NC       0   2024         NaN
